# %% [markdown]
# ### EXERCISE 8.2.8.
#
# Prove:
#
# If $\mathcal{R} = (\Gamma, V , B)$ is eventually contracting, $V$ is closed in $\mathbb{R}^X$ and $T$ is the Bellman operator generated by $\mathcal{R}$, then $T$ is globally stable on $V$.

# %% [markdown]
# **Proof**
#
# By Proposition 8.2.4., $\mathcal{R}$ is globally stable. Hence, $T$ has a unique fixed point in $v^* \in V$.
#
#
# First, we prove that for all $v\le v^*$,
